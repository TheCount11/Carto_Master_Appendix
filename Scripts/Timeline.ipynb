# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime
from matplotlib.lines import Line2D

levels = np.array([-1,6,-2, 1, -3, 3, -1, 1])
names = ['Begin', 'World Refugee Day,2016','Calais Jungle destroyed','Muslim Ban','Muslim ban', 'World Refugee Day,2017', 'Moria burns', 'End']
dates = ['2016-03','2016-06','2016-10','2017-01','2017-02', '2017-06', '2016-09','2021-01']
dates = [datetime.strptime(d, "%Y-%m") for d in dates]

levels2 = np.array([-2, 2, -1,])
names2 = ['Prince Harry and Megan Markle wedding', 'Boris Johnson is PM', 'First Covid-19 death of a UK citizen']
dates2 = ['2018-05', '2019-07', '2020-02']
dates2 = [datetime.strptime(d, "%Y-%m") for d in dates2]

custom_lines = [Line2D([0],[0],color="tab:red",lw=1, label = 'Events from tweet data'),
                Line2D([0],[0],color="tab:green",lw =1, label = 'Events reported on news')]

fig, ax = plt.subplots(figsize=(16.8, 8), constrained_layout=True)

ax.vlines(dates, 0, levels, color="tab:red")  # The vertical stems.
ax.plot(dates, np.zeros_like(dates), "-o",
        color="k", markerfacecolor="w")  # Baseline and markers on it.

for d, l, r in zip(dates, levels, names):
    ax.annotate(r, xy=(d, l),
                xytext=(-3, np.sign(l)*3), textcoords="offset points",
                horizontalalignment="right",
                verticalalignment="bottom" if l > 0 else "top",size =15)
    
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
plt.setp(ax.get_xticklabels(), rotation=30, ha="right")
plt.setp((ax.get_yticklabels() + ax.get_yticklines() +
              list(ax.spines.values())), visible=False)

ax.vlines(dates2, 0, levels2, color="tab:green")  # The vertical stems.
ax.plot(dates2, np.zeros_like(dates2), "-o",
        color="k", markerfacecolor="w")  # Baseline and markers on it.

for d, l, r in zip(dates2, levels2, names2):
    ax.annotate(r, xy=(d, l),
                xytext=(3, np.sign(l)*3), textcoords="offset points",
                horizontalalignment="center",
                verticalalignment="bottom" if l > 0 else "top",size =15)
ax.legend(handles = custom_lines,loc ='upper right',prop = dict(size=15))
plt.savefig('english_tweets.jpeg',pil_kwargs={'quality':95},bbox_inches = 'tight')
plt.show()

# %%
levels = np.array([-1,2,-2, 1, -3, 3, -1, 1])
names = ['Begin', 'Closing of Balkan route','World Refugee Day','AFD beats CDU in Berlin','Seehofer threatens to resign', 'Merkel gov. crisis', 'Muslim ban', 'End']
dates = ['2016-03','2016-04','2016-06','2016-09','2018-06', '2018-07', '2017-01','2021-01']
dates = [datetime.strptime(d, "%Y-%m") for d in dates]

levels2 = np.array([-2, 2, -1,])
names2 = ["Merkel's last term as Chancellor", 'Green Vault Robbery in Dresden', 'Covid-19 Lockdown ']
dates2 = ['2017-09', '2019-11', '2020-03']
dates2 = [datetime.strptime(d, "%Y-%m") for d in dates2]

custom_lines = [Line2D([0],[0],color="tab:red",lw=1, label = 'Events from tweet data'),
                Line2D([0],[0],color="tab:green",lw =1, label = 'Events reported on news')]

fig, ax = plt.subplots(figsize=(16.8, 8), constrained_layout=True)


ax.vlines(dates, 0, levels, color="tab:red")  # The vertical stems.
ax.plot(dates, np.zeros_like(dates), "-o",
        color="k", markerfacecolor="w")  # Baseline and markers on it.

for d, l, r in zip(dates, levels, names):
    ax.annotate(r, xy=(d, l),
                xytext=(-3, np.sign(l)*3), textcoords="offset points",
                horizontalalignment="left",
                verticalalignment="bottom" if l > 0 else "top",size =15)
    
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
plt.setp(ax.get_xticklabels(), rotation=30, ha="right")
plt.setp((ax.get_yticklabels() + ax.get_yticklines() +
              list(ax.spines.values())), visible=False)

ax.vlines(dates2, 0, levels2, color="tab:green")  # The vertical stems.
ax.plot(dates2, np.zeros_like(dates2), "o",color="k", markerfacecolor="w")  # Baseline and markers on it.

for d, l, r in zip(dates2, levels2, names2):
    ax.annotate(r, xy=(d, l),
                xytext=(3, np.sign(l)*3), textcoords="offset points",
                horizontalalignment="center",
                verticalalignment="bottom" if l > 0 else "top",size=15)
ax.legend(handles = custom_lines,loc ='upper right',prop = dict(size=15))
plt.savefig('german_tweets.jpeg',pil_kwargs={'quality':95},bbox_inches = 'tight')
plt.show()
